# %%
import pandas as pd
df= pd.read_csv('human_resource.csv')
df.head()
# Out:
#            id first_name    last_name date_of_birth  gender  \
# 0  00-0037846      Kimmy   Walczynski    04-06-1991    Male
# 1  00-0041533   Ignatius    Springett    29-06-1984    Male
# 2  00-0045747     Corbie  Bittlestone    29-07-1989    Male
# 3  00-0055274       Baxy       Matton    14-09-1982  Female
# 4  00-0076100    Terrell         Suff    11-04-1994  Female
#
#                         race            department  \
# 0         Hispanic or Latino           Engineering
# 1                      White  Business Development
# 2  Black or African American                 Sales
# 3                      White              Services
# 4          Two or More Races    Product Management
#
#                     job_title      location   hire_date  \
# 0        Programmer Analyst I  Headquarters  20-01-2002
# 1            Business Analyst  Headquarters  08-04-2019
# 2  Solutions Engineer Manager  Headquarters  12-10-2010
# 3                Service Tech  Headquarters  10-04-2005
# ...

# %%
df.describe(include = 'all')
# Out:
#                 id first_name last_name date_of_birth gender   race  \
# count        22214      22214     22214         22214  22214  22214
# unique       22214       7758     17754         10854      3      7
# top     00-0037846     Cassie    Ducker    09-05-1972   Male  White
# freq             1         12         7             9  11288   6328
#
#          department              job_title      location   hire_date  \
# count         22214                  22214         22214       22214
# unique           13                    185             2        7016
# top     Engineering  Research Assistant II  Headquarters  06-07-2009
# freq           6686                    754         16715          10
#
#                       term_date location_city location_state
# count                      3929         22214          22214
# unique                     3929            77              7
# top     2029-10-29 06:09:38 UTC     Cleveland           Ohio
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# first_name            0
# last_name             0
# date_of_birth         0
# gender                0
# race                  0
# department            0
# job_title             0
# location              0
# hire_date             0
# term_date         18285
# location_city         0
# location_state        0
# dtype: int64

# %%
df['term_date'] = pd.to_datetime(df['term_date'])
df['term_date'] = df.groupby('department')['term_date'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# id                0
# first_name        0
# last_name         0
# date_of_birth     0
# gender            0
# race              0
# department        0
# job_title         0
# location          0
# hire_date         0
# term_date         0
# location_city     0
# location_state    0
# dtype: int64

# %%
df.describe()
# Out:
#                 id first_name last_name date_of_birth gender   race  \
# count        22214      22214     22214         22214  22214  22214
# unique       22214       7758     17754         10854      3      7
# top     00-0037846     Cassie    Ducker    09-05-1972   Male  White
# freq             1         12         7             9  11288   6328
# mean           NaN        NaN       NaN           NaN    NaN    NaN
# min            NaN        NaN       NaN           NaN    NaN    NaN
# 25%            NaN        NaN       NaN           NaN    NaN    NaN
# 50%            NaN        NaN       NaN           NaN    NaN    NaN
# 75%            NaN        NaN       NaN           NaN    NaN    NaN
# max            NaN        NaN       NaN           NaN    NaN    NaN
#
#          department              job_title      location   hire_date  \
# count         22214                  22214         22214       22214
# unique           13                    185             2        7016
# ...

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'date_of_birth', 'gender', 'race',
#        'department', 'job_title', 'location', 'hire_date', 'term_date',
#        'location_city', 'location_state'],
#       dtype='object')

# %%
from urllib.parse import quote_plus
from sqlalchemy import create_engine


username = "postgres"
password = "@Skataria123"
host = "localhost"
port = "5432"
database = "hr_dashboard"

encoded_password = quote_plus(password)
engine = create_engine(f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}")

table_name = "dashboard"
df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Data successfully loaded into table '{table_name}' , '{database}'." )
# Out:
# Data successfully loaded into table 'dashboard' , 'hr_dashboard'.
